# %% [markdown]
# #### **Public Support channel data cleaning**

# %% [markdown]
# **Install and import libraries**

# %%
# %%capture
pip install numpy pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Load the data**

# %%
df_slack = pd.read_csv('../sources/support_channels.csv')

# %% [markdown]
# **Basic information about the data**

# %%
print('Shape of the dataframe before cleaning:', df_slack.shape)
# Out:
# Shape of the dataframe before cleaning: (500, 14)

# %%
df_slack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel_ID        500 non-null    object
#  1   Channel_Slug      500 non-null    object
#  2   Timestamp         500 non-null    object
#  3   Timestamp_Thread  337 non-null    object
#  4   User_ID           500 non-null    object
#  5   Full_Name         498 non-null    object
#  6   Email             500 non-null    object
#  7   Permalink         500 non-null    object
#  8   Text              500 non-null    object
#  9   Text_raw          491 non-null    object
#  10  Slack_username    500 non-null    object
#  11  Team_ID           500 non-null    object
#  12  Team_Name         500 non-null    object
#  13  Is_Bot            500 non-null    bool
# dtypes: bool(1), object(13)
# memory usage: 51.4+ KB

# %%
df_slack.sample(5)
# Out:
#     Channel_ID               Channel_Slug            Timestamp  \
# 291  CAZ9W99U4  public-support-full-stack   11/26/2022 2:52:16
# 64   CAZ9W99U4  public-support-full-stack  11/11/2022 16:12:26
# 189  CAZ9W99U4  public-support-full-stack  11/19/2022 18:35:44
# 92   CAZ9W99U4  public-support-full-stack    12/3/2022 2:44:06
# 67   CAZ9W99U4  public-support-full-stack   11/3/2022 14:50:07
#
#        Timestamp_Thread      User_ID                Full_Name  \
# 291  11/26/2022 2:42:32  U04B00WBB7B  Francisca Morales Moore
# 64                  NaN  U03A7FCVDMW          Richard Jardine
# 189                 NaN  U042JTZUFAN         Carlos Velazquez
# 92   12/2/2022 20:13:07  U03F8RRA9TR             Bairon Navia
# 67    11/3/2022 5:48:56  U03ACPHUXL7            Tyson Roussel
#
#                              Email  \
# 291           fraanmoore@gmail.com
# 64             rhjardine@gmail.com
# 189  95.carlos.velazquez@gmail.com
# 92             bairon97@icloud.com
# 67            tysonr0319@gmail.com
#
#                                              Permalink  \
# 291  https://4geeksacademy.slack.com/archives/CAZ9W...
# 64   https://4geeksacademy.slack.com/archives/CAZ9W...
# 189  https://4geeksacademy.slack.com/archives/CAZ9W...
# 92   https://4geeksacademy.slack.com/archives/CAZ9W...
# 67   https://4geeksacademy.slack.com/archives/CAZ9W...
#
#                                                   Text  \
# 291                       @dmoret17 cómo se haría eso?
# 64   Hello. Please, I require guidance regarding th...
# 189  Buenas tardes!!\n\nHe estado practicando los e...
# 92            tengo que pedir una mentoria para esto ?
# 67   Hey, did you double check that you have both c...
#
#                                               Text_raw       Slack_username  \
# 291                  <@U03RFM3C7DL> cómo se haría eso?           fraanmoore
# 64   Hello. Please, I require guidance regarding th...            rhjardine
# 189  Buenas tardes!!\n\nHe estado practicando los e...  95.carlos.velazquez
# 92            tengo que pedir una mentoria para esto ?             bairon97
# 67   Hey, did you double check that you have both c...           tysonr0319
#
#        Team_ID       Team_Name  Is_Bot
# 291  T0BFXMWMV  4Geeks Academy   False
# 64   T0BFXMWMV  4Geeks Academy   False
# 189  T0BFXMWMV  4Geeks Academy   False
# 92   T0BFXMWMV  4Geeks Academy   False
# 67   T0BFXMWMV  4Geeks Academy   False

# %%
df_slack['Channel_ID'].value_counts()
# Out:
# CAZ9W99U4    500
# Name: Channel_ID, dtype: int64

# %%
df_slack['Channel_Slug'].value_counts()
# Out:
# public-support-full-stack    500
# Name: Channel_Slug, dtype: int64

# %%
df_slack['Team_ID'].value_counts()
# Out:
# T0BFXMWMV    500
# Name: Team_ID, dtype: int64

# %%
df_slack['Team_Name'].value_counts()
# Out:
# 4Geeks Academy    500
# Name: Team_Name, dtype: int64

# %%
# Estas cuatro columnas no aportan información, por lo tanto considero apropiado eliminarlas.

df_slack.drop(columns=['Channel_ID', 'Channel_Slug', 'Team_ID', 'Team_Name'], inplace=True)

# %% [markdown]
# **Create, encode and transform columns**

# %%
df_slack['Is_a_question'] = np.where(df_slack['Timestamp_Thread'].isnull(), 1, 0)

# %%
# support_agent_ids = ['1','5301'] 
# No coincide el ID, por lo menos en el caso de Alejandro es UL08NNSV8
# support_agent_names = ['Alejandro Sanchez','Tomas Gonzalez']
# Es posible que a futuro se sumen otras personas con igual nombre. Considero más seguro usar el mail como referencia

support_agent_emails = ['aalejo@gmail.com', 'tgonzalez@4geeksacademy.com']

df_slack['Is_agent'] = np.where(df_slack['Email'].isin(support_agent_emails), 1, 0)

# %%
df_slack['Is_Bot'] = np.where(df_slack['Is_Bot'] == True, 1, 0)

# %%
df_slack['Datetime'] = pd.to_datetime(df_slack['Timestamp'])
df_slack['Datetime_Thread'] = pd.to_datetime(df_slack['Timestamp_Thread'])

# %% [markdown]
# **Create a dataframe for questions and another one for answers**

# %%
Q_df = df_slack[df_slack['Is_a_question'] == 1]
A_df = df_slack[df_slack['Is_a_question'] == 0]

# %% [markdown]
# **Perform transformations on the Questions dataframe**

# %%
questions = Q_df.groupby(['User_ID','Datetime'])[['Text']]

df_questions = pd.DataFrame(questions.sum().reset_index())

# %%
df_questions.head()
# Out:
#        User_ID            Datetime  \
# 0  U01J1EA8JN7 2022-12-07 14:42:41
# 1  U01SJ480RBR 2022-11-07 16:59:39
# 2  U01SM5J4MMG 2022-11-07 21:15:26
# 3  U026XFJHQPK 2022-12-14 13:34:18
# 4  U02G5B470B1 2022-11-15 19:07:30
#
#                                                 Text
# 0  Gente alguien sabe como se le puede agregar a ...
# 1                                              Hello
# 2      Buenas tardes, intenta poniendo solo git push
# 3  Hello, good afternoon for the people in europe...
# 4  Hello, where do I found the webpacks options a...

# %%
df_questions.shape
# Out:
# (162, 3)

# %%
df_questions['Diff_in_seconds'] = (df_questions.sort_values('Datetime').groupby('User_ID').Datetime.diff())

# %%
df_questions['Diff_in_seconds'] = df_questions['Diff_in_seconds'].fillna(pd.Timedelta(seconds=0))

# %%
df_questions['Diff_in_seconds']=df_questions['Diff_in_seconds']/np.timedelta64(1,'s')

# %%
df_questions['Diff_abs'] = df_questions['Diff_in_seconds'].abs()

# %%
df_questions['Not_previous_author'] = df_questions['User_ID'].ne(df_questions['User_ID'].shift().bfill()).astype(int)

# %%
def create_QuestionId(df):
    for group in df.groupby(['User_ID']):
        df['Q_message_ID'] = df['Diff_abs'].gt(300).cumsum() + 1 + df['Not_previous_author'].cumsum()
    return df

create_QuestionId(df_questions)
# Out:
# /tmp/ipykernel_2483/2402782191.py:2: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group in df.groupby(['User_ID']):
#          User_ID            Datetime  \
# 0    U01J1EA8JN7 2022-12-07 14:42:41
# 1    U01SJ480RBR 2022-11-07 16:59:39
# 2    U01SM5J4MMG 2022-11-07 21:15:26
# 3    U026XFJHQPK 2022-12-14 13:34:18
# 4    U02G5B470B1 2022-11-15 19:07:30
# ..           ...                 ...
# 157  U04GCSDB561 2023-01-02 17:54:14
# 158  U04GCSDB561 2023-01-03 15:35:26
# 159  U04GEJB6GBX 2023-01-02 07:47:22
# 160    U6MR8LG4Q 2022-11-05 03:11:30
# 161    UL08NNSV8 2022-11-01 18:39:22
#
#                                                   Text  Diff_in_seconds  \
# 0    Gente alguien sabe como se le puede agregar a ...              0.0
# 1                                                Hello              0.0
# 2        Buenas tardes, intenta poniendo solo git push              0.0
# 3    Hello, good afternoon for the people in europe...              0.0
# 4    Hello, where do I found the webpacks options a...              0.0
# ..                                                 ...              ...
# 157  Hola buenas tardes a todos. Estoy en el primer...         263262.0
# 158  Hola, buenos dias. Estoy tratando de que mis i...          78072.0
# 159  Hola! Estoy teniendo problemas para hacer un c...              0.0
# 160  Hey @betomasia12 No need to make the pictures ...              0.0
# 161  pareciera que tienes una version de ruby muy a...              0.0
#
#      Diff_abs  Not_previous_author  Q_message_ID
# 0         0.0                    0             1
# 1         0.0                    1             2
# 2         0.0                    1             3
# 3         0.0                    1             4
# 4         0.0                    1             5
# ..        ...                  ...           ...
# 157  263262.0                    0           135
# 158   78072.0                    0           136
# 159       0.0                    1           137
# 160       0.0                    1           138
# 161       0.0                    1           139
#
# [162 rows x 7 columns]

# %%
df_questions.shape
# Out:
# (162, 7)

# %%
# Merge the dataframe to its previous columns
df_questions = df_questions.merge(Q_df, how = 'left', left_on = ['User_ID', 'Datetime', 'Text'],
    right_on = ['User_ID', 'Datetime', 'Text']).drop(['Diff_in_seconds','Diff_abs','Not_previous_author','Text_raw'], axis=1)

# %%
df_questions.shape
# Out:
# (162, 14)

# %%
# Example before merging text
df_questions[df_questions['Q_message_ID']==131]
# Out:
#          User_ID            Datetime  \
# 150  U04F75G4970 2022-12-27 20:28:37
# 151  U04F75G4970 2022-12-27 20:28:44
# 152  U04F75G4970 2022-12-27 20:29:15
# 153  U04F75G4970 2022-12-27 20:29:19
#
#                                                   Text  Q_message_ID  \
# 150  Hola buenas, alguien me podría ayudar? Al agre...           131
# 151                                          image.png           131
# 152                                          image.png           131
# 153                                            Gracias           131
#
#                Timestamp Timestamp_Thread Full_Name  \
# 150  12/27/2022 20:28:37              NaN  Ignacio
# 151  12/27/2022 20:28:44              NaN  Ignacio
# 152  12/27/2022 20:29:15              NaN  Ignacio
# 153  12/27/2022 20:29:19              NaN  Ignacio
#
#                          Email  \
# 150  ignacio.damanes@gmail.com
# 151  ignacio.damanes@gmail.com
# 152  ignacio.damanes@gmail.com
# 153  ignacio.damanes@gmail.com
#
#                                              Permalink   Slack_username  \
# 150  https://4geeksacademy.slack.com/archives/CAZ9W...  ignacio.damanes
# 151  https://4geeksacademy.slack.com/archives/CAZ9W...  ignacio.damanes
# 152  https://4geeksacademy.slack.com/archives/CAZ9W...  ignacio.damanes
# 153  https://4geeksacademy.slack.com/archives/CAZ9W...  ignacio.damanes
#
#      Is_Bot  Is_a_question  Is_agent Datetime_Thread
# 150     0.0            1.0       0.0             NaT
# 151     0.0            1.0       0.0             NaT
# 152     0.0            1.0       0.0             NaT
# 153     0.0            1.0       0.0             NaT

# %%
# Merge text in rows that have the same Q_message_ID
df_questions['Text'] = df_questions.groupby(['Q_message_ID'])['Text'].transform(lambda x : ' '.join(x))

# %%
# Example after merging text
df_questions[df_questions['Q_message_ID']==131]
# Out:
#          User_ID            Datetime  \
# 150  U04F75G4970 2022-12-27 20:28:37
# 151  U04F75G4970 2022-12-27 20:28:44
# 152  U04F75G4970 2022-12-27 20:29:15
# 153  U04F75G4970 2022-12-27 20:29:19
#
#                                                   Text  Q_message_ID  \
# 150  Hola buenas, alguien me podría ayudar? Al agre...           131
# 151  Hola buenas, alguien me podría ayudar? Al agre...           131
# 152  Hola buenas, alguien me podría ayudar? Al agre...           131
# 153  Hola buenas, alguien me podría ayudar? Al agre...           131
#
#                Timestamp Timestamp_Thread Full_Name  \
# 150  12/27/2022 20:28:37              NaN  Ignacio
# 151  12/27/2022 20:28:44              NaN  Ignacio
# 152  12/27/2022 20:29:15              NaN  Ignacio
# 153  12/27/2022 20:29:19              NaN  Ignacio
#
#                          Email  \
# 150  ignacio.damanes@gmail.com
# 151  ignacio.damanes@gmail.com
# 152  ignacio.damanes@gmail.com
# 153  ignacio.damanes@gmail.com
#
#                                              Permalink   Slack_username  \
# 150  https://4geeksacademy.slack.com/archives/CAZ9W...  ignacio.damanes
# 151  https://4geeksacademy.slack.com/archives/CAZ9W...  ignacio.damanes
# 152  https://4geeksacademy.slack.com/archives/CAZ9W...  ignacio.damanes
# 153  https://4geeksacademy.slack.com/archives/CAZ9W...  ignacio.damanes
#
#      Is_Bot  Is_a_question  Is_agent Datetime_Thread
# 150     0.0            1.0       0.0             NaT
# 151     0.0            1.0       0.0             NaT
# 152     0.0            1.0       0.0             NaT
# 153     0.0            1.0       0.0             NaT

# %%
# Delete empty columns
df_questions.dropna(axis=1, how='all', inplace=True)

# %%
df_questions.shape
# Out:
# (162, 12)

# %%
# Merge timestamp in rows that have the same Q_message_ID
df_questions['Timestamp'] = df_questions.groupby(['Q_message_ID'])['Timestamp'].transform(lambda x : ','.join(map(str, x)))

# %%
# Example after merging timestamp
df_questions[df_questions['Q_message_ID']==131]
# Out:
#          User_ID            Datetime  \
# 150  U04F75G4970 2022-12-27 20:28:37
# 151  U04F75G4970 2022-12-27 20:28:44
# 152  U04F75G4970 2022-12-27 20:29:15
# 153  U04F75G4970 2022-12-27 20:29:19
#
#                                                   Text  Q_message_ID  \
# 150  Hola buenas, alguien me podría ayudar? Al agre...           131
# 151  Hola buenas, alguien me podría ayudar? Al agre...           131
# 152  Hola buenas, alguien me podría ayudar? Al agre...           131
# 153  Hola buenas, alguien me podría ayudar? Al agre...           131
#
#                                              Timestamp Full_Name  \
# 150  12/27/2022 20:28:37,12/27/2022 20:28:44,12/27/...  Ignacio
# 151  12/27/2022 20:28:37,12/27/2022 20:28:44,12/27/...  Ignacio
# 152  12/27/2022 20:28:37,12/27/2022 20:28:44,12/27/...  Ignacio
# 153  12/27/2022 20:28:37,12/27/2022 20:28:44,12/27/...  Ignacio
#
#                          Email  \
# 150  ignacio.damanes@gmail.com
# 151  ignacio.damanes@gmail.com
# 152  ignacio.damanes@gmail.com
# 153  ignacio.damanes@gmail.com
#
#                                              Permalink   Slack_username  \
# 150  https://4geeksacademy.slack.com/archives/CAZ9W...  ignacio.damanes
# 151  https://4geeksacademy.slack.com/archives/CAZ9W...  ignacio.damanes
# 152  https://4geeksacademy.slack.com/archives/CAZ9W...  ignacio.damanes
# 153  https://4geeksacademy.slack.com/archives/CAZ9W...  ignacio.damanes
#
#      Is_Bot  Is_a_question  Is_agent
# 150     0.0            1.0       0.0
# 151     0.0            1.0       0.0
# 152     0.0            1.0       0.0
# 153     0.0            1.0       0.0

# %%
# Rename columns to make it explicit that they correspond to questions
df_questions.rename(columns={'User_ID':'Q_User_ID', 'Datetime':'Q_Datetime', 'Text':'Q_Text', 
                            'Timestamp':'Q_Timestamp', 'Full_Name':'Q_Full_Name', 'Email':'Q_Email',
                            'Permalink':'Q_Permalink', 'Slack_username':'Q_Slack_username', 
                            'Is_agent':'Q_from_Agent'},inplace=True)

# %%
# Drop duplicates
df_questions.drop_duplicates(subset=["Q_Timestamp", "Q_Text"], keep='first', inplace=True)

# %%
df_questions.shape
# Out:
# (139, 12)

# %% [markdown]
# **Perform transformations on the Answers dataframe**

# %%
answers = A_df.groupby(['User_ID','Datetime'])[['Text']]

df_answers = pd.DataFrame(answers.sum().reset_index())

# %%
df_answers.head()
# Out:
#        User_ID            Datetime  \
# 0  U015XDM7KRA 2022-11-25 14:32:52
# 1  U01GE2A7HV4 2022-12-09 22:13:54
# 2  U01GE2A7HV4 2022-12-09 22:19:48
# 3  U01PE4CNXN1 2022-11-30 11:33:40
# 4  U01PE4CNXN1 2022-11-30 11:39:41
#
#                                                 Text
# 0  no te sirve redux o el context api ? por que f...
# 1  The statement indicates that you must give val...
# 2  Hint: In line 18 you have the element that you...
# 3     Yo te recomiendo netifly, es muy fácil de usar
# 4    Creo que sí, pero ahora mismo me haces dudar...

# %%
df_answers.shape
# Out:
# (337, 3)

# %%
df_answers['Diff_in_seconds'] = (df_answers.sort_values('Datetime').groupby('User_ID').Datetime.diff())

# %%
df_answers['Diff_in_seconds'] = df_answers['Diff_in_seconds'].fillna(pd.Timedelta(seconds=0))

# %%
df_answers['Diff_in_seconds']=df_answers['Diff_in_seconds']/np.timedelta64(1,'s')

# %%
df_answers['Diff_abs'] = df_answers['Diff_in_seconds'].abs()

# %%
df_answers['Not_previous_author'] = df_answers['User_ID'].ne(df_answers['User_ID'].shift().bfill()).astype(int)

# %%
def create_AnswerId(df):
    for group in df.groupby(['User_ID']):
        df['A_message_ID'] = df['Diff_abs'].gt(300).cumsum() + 1 + df['Not_previous_author'].cumsum()
    return df

create_AnswerId(df_answers)
# Out:
# /tmp/ipykernel_2483/3865329535.py:2: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group in df.groupby(['User_ID']):
#          User_ID            Datetime  \
# 0    U015XDM7KRA 2022-11-25 14:32:52
# 1    U01GE2A7HV4 2022-12-09 22:13:54
# 2    U01GE2A7HV4 2022-12-09 22:19:48
# 3    U01PE4CNXN1 2022-11-30 11:33:40
# 4    U01PE4CNXN1 2022-11-30 11:39:41
# ..           ...                 ...
# 332    UPRFXC3QE 2022-12-06 21:10:39
# 333    UPRFXC3QE 2022-12-07 16:28:05
# 334    UPRFXC3QE 2022-12-09 13:47:04
# 335    UU409472Q 2022-11-02 11:33:54
# 336    UU409472Q 2022-11-02 11:34:29
#
#                                                   Text  Diff_in_seconds  \
# 0    no te sirve redux o el context api ? por que f...              0.0
# 1    The statement indicates that you must give val...              0.0
# 2    Hint: In line 18 you have the element that you...            354.0
# 3       Yo te recomiendo netifly, es muy fácil de usar              0.0
# 4      Creo que sí, pero ahora mismo me haces dudar...            361.0
# ..                                                 ...              ...
# 332  There should be a free version. Check the othe...           1133.0
# 333  I dont know fly that well. You would need to r...          69446.0
# 334  Hi.  So the error is showing you do not have t...         163139.0
# 335  hay dos opciones\ne.key o e.keycode , en ambas...              0.0
# 336  si es e.key comparas con "Enter" , si es e.key...             35.0
#
#      Diff_abs  Not_previous_author  A_message_ID
# 0         0.0                    0             1
# 1         0.0                    1             2
# 2       354.0                    0             3
# 3         0.0                    1             4
# 4       361.0                    0             5
# ..        ...                  ...           ...
# 332    1133.0                    0           234
# 333   69446.0                    0           235
# 334  163139.0                    0           236
# 335       0.0                    1           237
# 336      35.0                    0           237
#
# [337 rows x 7 columns]

# %%
df_answers.shape
# Out:
# (337, 7)

# %%
# Merge the dataframe to its previous columns
df_answers = df_answers.merge(A_df, how = 'left', left_on = ['User_ID', 'Datetime', 'Text'],
    right_on = ['User_ID', 'Datetime', 'Text']).drop(['Diff_in_seconds','Diff_abs','Not_previous_author','Text_raw'], axis=1)

# %%
df_answers['Response_time'] = df_answers['Datetime'] - df_answers['Datetime_Thread']

# %%
df_answers.shape
# Out:
# (337, 15)

# %%
# Example before merging text
df_answers[df_answers['A_message_ID']==7]
# Out:
#         User_ID            Datetime  \
# 7   U01RCAJB6ES 2022-12-04 11:26:25
# 8   U01RCAJB6ES 2022-12-04 11:29:22
# 9   U01RCAJB6ES 2022-12-04 11:29:28
# 10  U01RCAJB6ES 2022-12-04 11:32:56
#
#                                                  Text  A_message_ID  \
# 7                      Pero no lo pongas entre llaves             7
# 8   element.lucky_numbers.forEach(number =&gt; { \...             7
# 9                                     Algo así sería              7
# 10  Aún así, no se suele usar for each, usa map pa...             7
#
#              Timestamp    Timestamp_Thread               Full_Name  \
# 7   12/4/2022 11:26:25  12/4/2022 10:46:37  David Berdiell sanchez
# 8   12/4/2022 11:29:22  12/4/2022 10:46:37  David Berdiell sanchez
# 9   12/4/2022 11:29:28  12/4/2022 10:46:37  David Berdiell sanchez
# 10  12/4/2022 11:32:56  12/4/2022 10:46:37  David Berdiell sanchez
#
#                          Email  \
# 7   david_berdiell@hotmail.com
# 8   david_berdiell@hotmail.com
# 9   david_berdiell@hotmail.com
# 10  david_berdiell@hotmail.com
#
#                                             Permalink  Slack_username  Is_Bot  \
# 7   https://4geeksacademy.slack.com/archives/CAZ9W...  david_berdiell       0
# 8   https://4geeksacademy.slack.com/archives/CAZ9W...  david_berdiell       0
# 9   https://4geeksacademy.slack.com/archives/CAZ9W...  david_berdiell       0
# 10  https://4geeksacademy.slack.com/archives/CAZ9W...  david_berdiell       0
#
#     Is_a_question  Is_agent     Datetime_Thread   Response_time
# 7               0         0 2022-12-04 10:46:37 0 days 00:39:48
# 8               0         0 2022-12-04 10:46:37 0 days 00:42:45
# 9               0         0 2022-12-04 10:46:37 0 days 00:42:51
# 10              0         0 2022-12-04 10:46:37 0 days 00:46:19

# %%
# Merge text in rows that have the same A_message_ID
df_answers['Text'] = df_answers.groupby(['A_message_ID'])['Text'].transform(lambda x : ' '.join(x))

# %%
# Example after merging text
df_answers[df_answers['A_message_ID']==7]
# Out:
#         User_ID            Datetime  \
# 7   U01RCAJB6ES 2022-12-04 11:26:25
# 8   U01RCAJB6ES 2022-12-04 11:29:22
# 9   U01RCAJB6ES 2022-12-04 11:29:28
# 10  U01RCAJB6ES 2022-12-04 11:32:56
#
#                                                  Text  A_message_ID  \
# 7   Pero no lo pongas entre llaves element.lucky_n...             7
# 8   Pero no lo pongas entre llaves element.lucky_n...             7
# 9   Pero no lo pongas entre llaves element.lucky_n...             7
# 10  Pero no lo pongas entre llaves element.lucky_n...             7
#
#              Timestamp    Timestamp_Thread               Full_Name  \
# 7   12/4/2022 11:26:25  12/4/2022 10:46:37  David Berdiell sanchez
# 8   12/4/2022 11:29:22  12/4/2022 10:46:37  David Berdiell sanchez
# 9   12/4/2022 11:29:28  12/4/2022 10:46:37  David Berdiell sanchez
# 10  12/4/2022 11:32:56  12/4/2022 10:46:37  David Berdiell sanchez
#
#                          Email  \
# 7   david_berdiell@hotmail.com
# 8   david_berdiell@hotmail.com
# 9   david_berdiell@hotmail.com
# 10  david_berdiell@hotmail.com
#
#                                             Permalink  Slack_username  Is_Bot  \
# 7   https://4geeksacademy.slack.com/archives/CAZ9W...  david_berdiell       0
# 8   https://4geeksacademy.slack.com/archives/CAZ9W...  david_berdiell       0
# 9   https://4geeksacademy.slack.com/archives/CAZ9W...  david_berdiell       0
# 10  https://4geeksacademy.slack.com/archives/CAZ9W...  david_berdiell       0
#
#     Is_a_question  Is_agent     Datetime_Thread   Response_time
# 7               0         0 2022-12-04 10:46:37 0 days 00:39:48
# 8               0         0 2022-12-04 10:46:37 0 days 00:42:45
# 9               0         0 2022-12-04 10:46:37 0 days 00:42:51
# 10              0         0 2022-12-04 10:46:37 0 days 00:46:19

# %%
# Merge timestamp in rows that have the same A_message_ID
df_answers['Timestamp'] = df_answers.groupby(['A_message_ID'])['Timestamp'].transform(lambda x : ','.join(map(str, x)))

# %%
# Example after merging timestamp
df_answers[df_answers['A_message_ID']==7]
# Out:
#         User_ID            Datetime  \
# 7   U01RCAJB6ES 2022-12-04 11:26:25
# 8   U01RCAJB6ES 2022-12-04 11:29:22
# 9   U01RCAJB6ES 2022-12-04 11:29:28
# 10  U01RCAJB6ES 2022-12-04 11:32:56
#
#                                                  Text  A_message_ID  \
# 7   Pero no lo pongas entre llaves element.lucky_n...             7
# 8   Pero no lo pongas entre llaves element.lucky_n...             7
# 9   Pero no lo pongas entre llaves element.lucky_n...             7
# 10  Pero no lo pongas entre llaves element.lucky_n...             7
#
#                                             Timestamp    Timestamp_Thread  \
# 7   12/4/2022 11:26:25,12/4/2022 11:29:22,12/4/202...  12/4/2022 10:46:37
# 8   12/4/2022 11:26:25,12/4/2022 11:29:22,12/4/202...  12/4/2022 10:46:37
# 9   12/4/2022 11:26:25,12/4/2022 11:29:22,12/4/202...  12/4/2022 10:46:37
# 10  12/4/2022 11:26:25,12/4/2022 11:29:22,12/4/202...  12/4/2022 10:46:37
#
#                  Full_Name                       Email  \
# 7   David Berdiell sanchez  david_berdiell@hotmail.com
# 8   David Berdiell sanchez  david_berdiell@hotmail.com
# 9   David Berdiell sanchez  david_berdiell@hotmail.com
# 10  David Berdiell sanchez  david_berdiell@hotmail.com
#
#                                             Permalink  Slack_username  Is_Bot  \
# 7   https://4geeksacademy.slack.com/archives/CAZ9W...  david_berdiell       0
# 8   https://4geeksacademy.slack.com/archives/CAZ9W...  david_berdiell       0
# 9   https://4geeksacademy.slack.com/archives/CAZ9W...  david_berdiell       0
# 10  https://4geeksacademy.slack.com/archives/CAZ9W...  david_berdiell       0
#
#     Is_a_question  Is_agent     Datetime_Thread   Response_time
# 7               0         0 2022-12-04 10:46:37 0 days 00:39:48
# 8               0         0 2022-12-04 10:46:37 0 days 00:42:45
# 9               0         0 2022-12-04 10:46:37 0 days 00:42:51
# 10              0         0 2022-12-04 10:46:37 0 days 00:46:19

# %%
# Rename columns to make it explicit that they correspond to answers
df_answers.rename(columns={'User_ID':'A_User_ID', 'Datetime':'A_Datetime', 'Text':'A_Text', 'Timestamp':'A_Timestamp', 
                            'Timestamp_Thread':'Key_to_Q_Timestamp', 'Full_Name':'A_Full_Name', 'Email':'A_Email', 
                            'Permalink':'A_Permalink', 'Slack_username':'A_Slack_username', 'Is_agent':'A_from_Agent',
                            'Datetime_Thread':'A_Datetime_Thread'},inplace=True)

# %%
df_answers = df_answers.drop_duplicates(subset=['A_Timestamp', 'A_Text'], keep='first')

# %%
df_answers.shape
# Out:
# (237, 15)

# %% [markdown]
# **Combine both dataframes**

# %%
question_ids_list = df_questions['Q_Timestamp'].tolist()

# %%
def id_autocompletion(search):
    for id in question_ids_list:
        if search in id:
            return id
    
    return None

# %%
df_answers['Key_to_Q_Timestamp'] =  df_answers['Key_to_Q_Timestamp'].apply(id_autocompletion)

# %%
df_answers['Key_to_Q_Timestamp'] =  np.where(df_answers['Key_to_Q_Timestamp'].isnull(), str(df_answers['A_Datetime_Thread']), df_answers['Key_to_Q_Timestamp'])

# %%
final_df = pd.merge(df_questions, df_answers, left_on = ['Q_Timestamp'], right_on = ['Key_to_Q_Timestamp'], how = 'left')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 0 to 213
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Q_User_ID           214 non-null    object
#  1   Q_Datetime          214 non-null    datetime64[ns]
#  2   Q_Text              214 non-null    object
#  3   Q_message_ID        214 non-null    int64
#  4   Q_Timestamp         214 non-null    object
#  5   Q_Full_Name         213 non-null    object
#  6   Q_Email             213 non-null    object
#  7   Q_Permalink         213 non-null    object
#  8   Q_Slack_username    213 non-null    object
#  9   Is_Bot_x            213 non-null    float64
#  10  Is_a_question_x     213 non-null    float64
#  11  Q_from_Agent        213 non-null    float64
#  12  A_User_ID           150 non-null    object
#  13  A_Datetime          150 non-null    datetime64[ns]
#  14  A_Text              150 non-null    object
#  15  A_message_ID        150 non-null    float64
#  16  A_Timestamp         150 non-null    object
#  17  Key_to_Q_Timestamp  150 non-null    object
#  18  A_Full_Name         150 non-null    object
#  19  A_Email             150 non-null    object
#  20  A_Permalink         150 non-null    object
#  21  A_Slack_username    150 non-null    object
#  22  Is_Bot_y            150 non-null    float64
#  23  Is_a_question_y     150 non-null    float64
#  24  A_from_Agent        150 non-null    float64
#  25  A_Datetime_Thread   150 non-null    datetime64[ns]
#  26  Response_time       150 non-null    timedelta64[ns]
# dtypes: datetime64[ns](3), float64(7), int64(1), object(15), timedelta64[ns](1)
# memory usage: 46.8+ KB

# %%
final_df.head()
# Out:
#      Q_User_ID          Q_Datetime  \
# 0  U01J1EA8JN7 2022-12-07 14:42:41
# 1  U01SJ480RBR 2022-11-07 16:59:39
# 2  U01SM5J4MMG 2022-11-07 21:15:26
# 3  U026XFJHQPK 2022-12-14 13:34:18
# 4  U02G5B470B1 2022-11-15 19:07:30
#
#                                               Q_Text  Q_message_ID  \
# 0  Gente alguien sabe como se le puede agregar a ...             1
# 1                                              Hello             2
# 2      Buenas tardes, intenta poniendo solo git push             3
# 3  Hello, good afternoon for the people in europe...             4
# 4  Hello, where do I found the webpacks options a...             5
#
#            Q_Timestamp                   Q_Full_Name  \
# 0   12/7/2022 14:42:41                      LucasVY
# 1   11/7/2022 16:59:39                Maikol Moreira
# 2   11/7/2022 21:15:26  Alvaro Javier Chagas Capurro
# 3  12/14/2022 13:34:18      Nicola Martinez Clemente
# 4  11/15/2022 19:07:30        Facundo Gul dos Santos
#
#                           Q_Email  \
# 0          Lucas.varasy@gmail.com
# 1           Niukeitor@hotmail.com
# 2  alvarojavierchagas@hotmail.com
# 3    nicoenrique_1994@hotmail.com
# 4            facundogds@gmail.com
#
#                                          Q_Permalink    Q_Slack_username  \
# 0  https://4geeksacademy.slack.com/archives/CAZ9W...        lucas.varasy
# 1  https://4geeksacademy.slack.com/archives/CAZ9W...           niukeitor
# 2  https://4geeksacademy.slack.com/archives/CAZ9W...  alvarojavierchagas
# 3  https://4geeksacademy.slack.com/archives/CAZ9W...    nicoenrique_1994
# 4  https://4geeksacademy.slack.com/archives/CAZ9W...          facundogds
#
#    Is_Bot_x  ...   Key_to_Q_Timestamp                   A_Full_Name  \
# 0       0.0  ...                  NaN                           NaN
# 1       0.0  ...                  NaN                           NaN
# 2       0.0  ...   11/7/2022 21:15:26  Alvaro Javier Chagas Capurro
# 3       0.0  ...                  NaN                           NaN
# 4       0.0  ...  11/15/2022 19:07:30        Facundo Gul dos Santos
#
#                           A_Email  \
# 0                             NaN
# 1                             NaN
# 2  alvarojavierchagas@hotmail.com
# 3                             NaN
# 4            facundogds@gmail.com
#
#                                          A_Permalink    A_Slack_username  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2  https://4geeksacademy.slack.com/archives/CAZ9W...  alvarojavierchagas
# 3                                                NaN                 NaN
# 4  https://4geeksacademy.slack.com/archives/CAZ9W...          facundogds
#
#    Is_Bot_y Is_a_question_y A_from_Agent   A_Datetime_Thread   Response_time
# 0       NaN             NaN          NaN                 NaT             NaT
# 1       NaN             NaN          NaN                 NaT             NaT
# 2       0.0             0.0          0.0 2022-11-07 21:15:26 0 days 16:54:13
# 3       NaN             NaN          NaN                 NaT             NaT
# 4       0.0             0.0          0.0 2022-11-15 19:07:30 0 days 00:20:48
#
# [5 rows x 27 columns]

# %%
final_df.to_csv('../outputs/final_df.csv')
